# %% [markdown]
# # Advent of Code 2025
# ## Python Solutions

# %% [markdown]
# ### Day 01: Secret Entrance

# %%
# part 1
from pathlib import Path

content = Path("d01.txt").read_text().splitlines()

ptr = 50
N = 100
counter = 0

def rotate(direction, number, ptr, counter):
    if direction == "L":
        ptr =  (ptr - number) % N
    else: # direction == "R" 
        ptr =  (ptr + number) % N

    if ptr == 0:
        counter += 1

    return ptr, counter

for move in content:
    direction = move[:1]
    number = int(move[1:])

    ptr, counter = rotate(direction, number, ptr, counter)


counter
# Out:
# 992

# %%
# part 2
content = Path("d01.txt").read_text().splitlines()
content

ptr = 50
N = 100
counter = 0

def rotate(direction, number, ptr, counter):
    if direction ==  "L":
        for _ in range(number):
            ptr = (ptr - 1) % N
            if ptr == 0:
                counter += 1
    else: # direction == "R"
        for _ in range(number):
            ptr = (ptr + 1) % N
            if ptr == 0:
                counter += 1

    return ptr, counter

for move in content:
    direction = move[:1]
    number = int(move[1:])

    ptr, counter = rotate(direction, number, ptr, counter)

counter
# Out:
# 6133

# %% [markdown]
# ### Day 02:
